# %%
import pandas as pd
sampah = pd.read_csv ('sampah_jabar.csv')
sampah
# Out:
#       id  kode_provinsi nama_provinsi  kode_kabupaten_kota  \
# 0      1             32    JAWA BARAT                 3201
# 1      2             32    JAWA BARAT                 3202
# 2      3             32    JAWA BARAT                 3203
# 3      4             32    JAWA BARAT                 3204
# 4      5             32    JAWA BARAT                 3205
# ..   ...            ...           ...                  ...
# 184  185             32    JAWA BARAT                 3275
# 185  186             32    JAWA BARAT                 3276
# 186  187             32    JAWA BARAT                 3277
# 187  188             32    JAWA BARAT                 3278
# 188  189             32    JAWA BARAT                 3279
#
#     nama_kabupaten_kota  jumlah_produksi_sampah        satuan  tahun
# 0       KABUPATEN BOGOR                 1511.15  TON PER HARI   2015
# 1    KABUPATEN SUKABUMI                  419.01  TON PER HARI   2015
# ...

# %%
jmlh_2019 = sampah[sampah['tahun'] == 2019]['jumlah_produksi_sampah'].sum()
print(f'jumlah total sampah ditahun 2019: {jmlh_2019}')
# Out:
# jumlah total sampah ditahun 2019: 24490.56

# %%
jmlh_2015 = sampah[sampah['tahun'] == 2015]['jumlah_produksi_sampah'].sum()
print(f'jumlah total sampah ditahun 2015: {jmlh_2015}')
jmlh_2016 = sampah[sampah['tahun'] == 2016]['jumlah_produksi_sampah'].sum()
print(f'jumlah total sampah ditahun 2016: {jmlh_2016}')
jmlh_2017 = sampah[sampah['tahun'] == 2017]['jumlah_produksi_sampah'].sum()
print(f'jumlah total sampah ditahun 2017: {jmlh_2017}')
jmlh_2018 = sampah[sampah['tahun'] == 2018]['jumlah_produksi_sampah'].sum()
print(f'jumlah total sampah ditahun 2018: {jmlh_2018}')
jmlh_2019 = sampah[sampah['tahun'] == 2019]['jumlah_produksi_sampah'].sum()
print(f'jumlah total sampah ditahun 2019: {jmlh_2019}')
jmlh_2020 = sampah[sampah['tahun'] == 2020]['jumlah_produksi_sampah'].sum()
print(f'jumlah total sampah ditahun 2020: {jmlh_2020}')
jmlh_2021 = sampah[sampah['tahun'] == 2021]['jumlah_produksi_sampah'].sum()
print(f'jumlah total sampah ditahun 2021: {jmlh_2021}')
# Out:
# jumlah total sampah ditahun 2015: 20969.269999999997
# jumlah total sampah ditahun 2016: 20969.269999999997
# jumlah total sampah ditahun 2017: 20969.269999999997
# jumlah total sampah ditahun 2018: 22772.92
# jumlah total sampah ditahun 2019: 24490.56
# jumlah total sampah ditahun 2020: 25333.0
# jumlah total sampah ditahun 2021: 15735.360000000002

# %%
for index, row in sampah.iterrows():
    print(f'{index+1}. {row['nama_kabupaten_kota']} dengan total sampah {row['jumlah_produksi_sampah']} pada tahun {row['tahun']}')
# Out:
# 1. KABUPATEN BOGOR dengan total sampah 1511.15 pada tahun 2015
# 2. KABUPATEN SUKABUMI dengan total sampah 419.01 pada tahun 2015
# 3. KABUPATEN CIANJUR dengan total sampah 981.41 pada tahun 2015
# 4. KABUPATEN BANDUNG dengan total sampah 1895.94 pada tahun 2015
# 5. KABUPATEN GARUT dengan total sampah 464.74 pada tahun 2015
# 6. KABUPATEN TASIKMALAYA dengan total sampah 464.52 pada tahun 2015
# 7. KABUPATEN CIAMIS dengan total sampah 260.91 pada tahun 2015
# 8. KABUPATEN KUNINGAN dengan total sampah 251.7 pada tahun 2015
# 9. KABUPATEN CIREBON dengan total sampah 465.75 pada tahun 2015
# 10. KABUPATEN MAJALENGKA dengan total sampah 254.63 pada tahun 2015
# 11. KABUPATEN SUMEDANG dengan total sampah 237.96 pada tahun 2015
# 12. KABUPATEN INDRAMAYU dengan total sampah 613.18 pada tahun 2015
# 13. KABUPATEN SUBANG dengan total sampah 487.26 pada tahun 2015
# 14. KABUPATEN PURWAKARTA dengan total sampah 308.96 pada tahun 2015
# ...
